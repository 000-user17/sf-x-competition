# %%
from test6 import class_init

# %%
import json
with open('g2.json', 'r') as file:
    # 加载JSON文件数据
    g3_data = json.load(file)
g3 = class_init(g3_data)
g3.map_process()
# Out:
# 0.0
# 0.0020046234130859375
# 0.014991283416748047
# 0.006996870040893555
# 0.00800013542175293
# 0.006999969482421875
# 0.007998943328857422
# 0.00600123405456543
# 0.006999492645263672
# 0.005999326705932617
# 0.00599980354309082
# 0.0070002079010009766
# 0.00599980354309082
# 0.006000041961669922
# 0.006000041961669922
# 0.006000041961669922
# 0.00599980354309082
# 0.0060002803802490234
# 0.006003141403198242
# 0.0059967041015625
# 0.0070035457611083984
# 0.0059967041015625
# 0.00599980354309082
# 0.006000041961669922
# 0.00599980354309082
# 0.006000041961669922
# 0.006000518798828125
# 0.005999565124511719
# 0.00599980354309082
# 0.006000041961669922
# 0.006000041961669922
# 0.00599980354309082
# 0.0060007572174072266
# 0.005999565124511719
# 0.006000041961669922
# 0.007000923156738281
# 0.005999326705932617
# 0.006000518798828125
# 0.006000518798828125
# 0.00599980354309082
# 0.00599980354309082
# 0.006000041961669922
# 0.0060117244720458984
# 0.006989955902099609
# ...

# %%
print(g3.ACTIONS_SEQ1)
# Out:
# [[{'type': 'MOVE', 'dir': 'RIGHT'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}], [{'type': 'MOVE', 'dir': 'UP'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}], [{'type': 'MOVE', 'dir': 'UP'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}], [{'type': 'MOVE', 'dir': 'UP'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}, {'type': 'STAY'}], [{'type': 'MOVE', 'dir': 'UP'}, {'type': 'STAY'}, {'type': 'STAY'}, {'
# ...
